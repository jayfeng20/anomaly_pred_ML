# %%
import cycleFetch as cf
from datetime import datetime, timedelta
import pyodbc
import os
import datetime
import calendar
import json

# %%
# set up db connections
dev_db_conn_str = os.environ["DEV_DB_ODBC_CONN_STR"]
prod_db_conn_str = os.environ["PROD_DB_ODBC_CONN_STR"]

dev_conn = pyodbc.connect(dev_db_conn_str)
prod_conn = pyodbc.connect(prod_db_conn_str)

dev_cursor = dev_conn.cursor()
prod_cursor = prod_conn.cursor()

# %%
# Fetch device PMCL number from device Pmcl description
sql = '''
SELECT PmclNumber, PmclDescription FROM VW_EquipHealthPmcl WHERE 
PmclDescription LIKE '%AMSCO 400 Medium%' group by PmclNumber, PmclDescription
'''
dev_cursor.execute(sql)
pmcl_pairs = dev_cursor.fetchall()

pmcl_dict = {x[0] : x[1] for x in pmcl_pairs}

# %%
# Fetch Customer Device IDs based on PMCL
# Form pcml: [customer_device1, ...] hashmap
pmcl_customr_device_dict = {}
for pmcl, desc in pmcl_dict.items():

    sql = f''' 
    SELECT CustomerDevice_Id FROM CustomerDevice
    WHERE SiebelSTEEquipType = '{pmcl}'
    '''
    prod_cursor.execute(sql)
    cd_lst = prod_cursor.fetchall()
    pmcl_customr_device_dict[pmcl] = cd_lst

print(pmcl_customr_device_dict)
# Out:
# {'764327358/02': [(4263,), (4264,), (4310,), (4311,), (4334,), (4335,), (4422,), (4423,), (6754,), (5821,), (5822,), (5885,), (5886,), (5888,), (6078,), (6079,), (6083,), (6084,), (6902,), (6221,), (6223,), (6373,), (6374,), (6384,), (6385,), (6652,), (6653,), (7030,), (7031,), (6773,), (5559,), (5560,), (5626,), (5734,), (5736,), (5737,), (4576,), (4577,), (6842,), (4826,), (4828,), (5050,), (5294,), (5295,), (5307,), (5308,), (5312,), (5313,), (5326,), (5327,), (5330,), (5331,), (5332,), (5333,), (2255,), (2256,), (2261,), (2262,), (2349,), (2350,), (2373,), (2374,), (2409,), (6848,), (6862,), (4717,), (4718,), (699,), (700,), (701,), (819,), (820,), (6903,), (4958,), (4968,), (4969,), (4984,), (4999,), (5103,), (5104,), (5126,), (5127,), (1427,), (1428,), (1429,), (1430,), (6952,), (6646,), (6650,), (5999,), (6000,), (6001,), (6011,), (6012,), (4395,), (4405,), (5209,), (5210,), (586,), (587,), (588,), (646,), (647,), (6251,), (6252,), (6253,), (6254,), (6255,), (6297,), (2463,), (2464,), (6496,), (6498,), (6772,), (2099,), (2535,), (2536,), (5528,), (5529,), (5530,), (5532,), (5537,), (5538,)], '764327358/01': [(101,), (137,), (6665,), (6699,), (6671,), (6698,), (6729,), (6748,), (6750,), (4272,), (4288,), (4293,), (4316,), (4317,), (4433,), (4446,), (6731,), (6733,), (6730,), (5823,), (5824,), (5825,), (5826,), (5827,), (5832,), (5833,), (5839,), (5840,), (5841,), (5845,), (5846,), (5849,), (5850,), (5852,), (5853,), (5854,), (5855,), (5856,), (5883,), (5894,), (5898,), (5901,), (5902,), (5936,), (5937,), (5938,), (5952,), (5953,), (5954,), (5955,), (5958,), (5972,), (6055,), (6056,), (6057,), (6069,), (6081,), (6103,), (6108,), (6123,), (6124,), (6125,), (6126,), (6130,), (6131,), (6132,), (6133,), (6139,), (6140,), (6141,), (6146,), (6156,), (6157,), (6881,), (6185,), (6186,), (6189,), (6190,), (6207,), (6214,), (6215,), (6226,), (6227,), (6229,), (6311,), (6312,), (6313,), (6317,), (6321,), (6325,), (6368,), (6383,), (6396,), (6402,), (6404,), (6408,), (6416,), (6433,), (6443,), (6502,), (6503,), (6504,), (6505,), (6506,), (6508,), (6509,), (6510,), (6672,), (7022,), (6989,), (7023,), (4479,), (4518,), (4520,), (6689,), (6766,), (6768,), (5585,), (5586,), (5587,), (5588,), (5589,), (5612,), (5613,), (5614,), (5621,), (5622,), (5708,), (5738,), (5748,), (5749,), (5785,), (6798,), (6819,), (6800,), (6809,), (6820,), (6732,), (7018,), (4554,), (4555,), (4567,), (4612,), (4616,), (4617,), (4635,), (4636,), (4637,), (4670,), (4671,), (4672,), (4781,), (4783,), (6884,), (6882,), (6808,), (6810,), (6817,), (4816,), (4817,), (4818,), (4860,), (5289,), (5290,), (5291,), (5292,), (5293,), (5316,), (5323,), (5377,), (5379,), (5380,), (5393,), (5394,), (5395,), (5411,), (5412,), (5420,), (2231,), (2232,), (2233,), (2250,), (2271,), (2272,), (2293,), (2323,), (2324,), (2345,), (2346,), (2352,), (2353,), (2393,), (2394,), (2396,), (6771,), (6818,), (4692,), (4693,), (4695,), (4740,), (4741,), (757,), (758,), (875,), (876,), (974,), (987,), (1004,), (1005,), (1006,), (4875,), (4876,), (4879,), (4880,), (4897,), (4899,), (4917,), (4918,), (4922,), (4950,), (4953,), (4954,), (4988,), (4989,), (5094,), (5095,), (5097,), (5099,), (5100,), (5101,), (5108,), (5109,), (5110,), (5111,), (5131,), (5132,), (7049,), (5670,), (5683,), (5684,), (5692,), (1452,), (1515,), (1516,), (1517,), (1596,), (1597,), (1598,), (1628,), (6700,), (6673,), (1748,), (1750,), (1751,), (1802,), (1805,), (1809,), (1810,), (6583,), (6584,), (6622,), (5975,), (5978,), (5989,), (5990,), (6019,), (1811,), (1819,), (1828,), (1839,), (1840,), (1902,), (1921,), (1938,), (1939,), (1940,), (1959,), (1960,), (1963,), (1981,), (2000,), (2001,), (2023,), (4347,), (4348,), (4349,), (4367,), (4368,), (4369,), (4385,), (4387,), (5184,), (5185,), (5186,), (390,), (492,), (535,), (6988,), (6987,), (5223,), (5224,), (5225,), (5226,), (5229,), (5269,), (5270,), (5274,), (5275,), (5279,), (5280,), (5444,), (5445,), (5447,), (5448,), (5449,), (6242,), (6243,), (6244,), (6248,), (6249,) ...

# %%
# fetch cycle id, starttime, endtime,
# Form device id: (cycle id, starttime, endtime) hashmap
# [{'pmcl': pmcl, 'devices': [{'deviceId': deviceId, 'cycle_ids': [{id, starttime, endtime, duration}]}]}]#

# return object in the following format:
# [{'pmcl': pmcl, 
#   'devices':[
#      {'deviceId': deviceId,
#       'cycle_ids': [{
#           'cycleId': id,
#           'starttime': starttime,
#           'endtime': endtime,
#           'duration': duration
#       }]}
#  ]}]

def add_cycle_data(pmcl_customer_device_dict):

    full_list = []
    cycle_not_in_connectcarereporting = []
    for pmcl, cd_list in pmcl_customr_device_dict.items():
        obj = {'pmcl': pmcl, 'devices': [] }

        for customer_device_id in cd_list:
            device = {}
            customer_device_id = customer_device_id[0]

            sql = f""" 
            SELECT DeviceCycle_Id, CycleStartDateTime, CycleEndDateTime, CycleType FROM UCBCycleData
            WHERE CustomerDeviceId = '{customer_device_id}' ORDER BY CycleStartDateTime ASC
            """
            sql2 = f""" 
            SELECT DeviceCycle_Id, CycleStartDateTime, CycleEndDateTime, CycleType FROM UCBCycleDataSecondary
            WHERE CustomerDeviceId = '{customer_device_id}' ORDER BY CycleStartDateTime ASC
            """

            prod_cursor.execute(sql)
            cycle_ids = prod_cursor.fetchall()
            if cycle_ids == []:
                # print(f"Device {customer_device_id}'s cycle data is not in the first table")
                prod_cursor.execute(sql2)
                cycle_ids = prod_cursor.fetchall()
            if cycle_ids == []:
                cycle_not_in_connectcarereporting.append(customer_device_id)

            else:
                cycle_ids_dict_list = []
                for row in cycle_ids:
                    row = list(row)
                    row[1] = calendar.timegm(row[1].timetuple())
                    row[2] = calendar.timegm(row[2].timetuple())
                    d = {"cycleId": row[0], "starttime": row[1], "endtime": row[2], 'duration':row[2]-row[1], 'type': row[3]}
                    cycle_ids_dict_list.append(d)
                    device['deviceId'] = customer_device_id
                    device['cycle_ids'] = cycle_ids_dict_list
            if len(device) != 0:
                obj['devices'].append(device)

        if obj['devices'] != []:
            full_list.append(obj)
    return full_list

# %%
full_list = add_cycle_data(pmcl_customr_device_dict)
print(full_list[0]['devices'][0]['cycle_ids'])
# Monitor which machines do not have cycle data in connectcarereporting
# with open("no_cycle_data.txt", 'w') as file:
#     for data in cycle_not_in_connectcarereporting:
#         file.write("%s\n" % data)
# Out:
# [{'cycleId': 12433368.0, 'starttime': 1646315016, 'endtime': 1646315987, 'duration': 971, 'type': 'DART WARMUP'}, {'cycleId': 12465041.0, 'starttime': 1646703543, 'endtime': 1646704641, 'duration': 1098, 'type': 'DART WARMUP'}, {'cycleId': 12465175.0, 'starttime': 1646704808, 'endtime': 1646706867, 'duration': 2059, 'type': 'LEAK TEST'}, {'cycleId': 12465308.0, 'starttime': 1646707802, 'endtime': 1646709651, 'duration': 1849, 'type': 'DART TEST'}, {'cycleId': 12465454.0, 'starttime': 1646710177, 'endtime': 1646711824, 'duration': 1647, 'type': 'DART TEST'}, {'cycleId': 12465654.0, 'starttime': 1646712715, 'endtime': 1646714373, 'duration': 1658, 'type': 'DART TEST'}, {'cycleId': 12466226.0, 'starttime': 1646714874, 'endtime': 1646719189, 'duration': 4315, 'type': 'PREVAC'}, {'cycleId': 12466488.0, 'starttime': 1646719617, 'endtime': 1646722925, 'duration': 3308, 'type': 'PREVAC'}, {'cycleId': 12471020.0, 'starttime': 1646765081, 'endtime': 1646769168, 'duration': 4087, 'type': 'PREVAC'}, {'cycleId': 12471349.0, 'starttime': 1646769601, 'endtime': 1646773510, 'duration': 3909, 'type': 'PREVAC'}, {'cycleId': 12473818.0, 'starttime': 1646801422, 'endtime': 1646802922, 'duration': 1500, 'type': 'DART TEST'}, {'cycleId': 12480616.0, 'starttime': 1646871115, 'endtime': 1646872798, 'duration': 1683, 'type': 'DART TEST'}, {'cycleId': 12488395.0, 'starttime': 1646958018, 'endtime': 1646960213, 'duration': 2195, 'type': 'DART TEST'}, {'cycleId': 12512951.0, 'starttime': 1647217327, 'endtime': 1647218018, 'duration': 691, 'type': 'DART WARMUP'}, {'cycleId': 12513054.0, 'starttime': 1647218287, 'endtime': 1647220171, 'duration': 1884, 'type': 'LEAK TEST'}, {'cycleId': 12513116.0, 'starttime': 1647221006, 'endtime': 1647222166, 'duration': 1160, 'type': 'DART TEST'}, {'cycleId': 12513171.0, 'starttime': 1647223108, 'endtime': 1647224250, 'duration': 1142, 'type': 'DART TEST'}, {'cycleId': 12513209.0, 'starttime': 1647225013, 'endtime': 1647226113, 'duration': 1100, 'type': 'DART TEST'}, {'cycleId': 12513592.0, 'starttime': 1647226713, 'endtime': 1647230485, 'duration': 3772, 'type': 'PREVAC'}, {'cycleId': 12513980.0, 'starttime': 1647230783, 'endtime': 1647234603, 'duration': 3820, 'type': 'PREVAC'}, {'cycleId': 12514341.0, 'starttime': 1647234762, 'endtime': 1647238573, 'duration': 3811, 'type': 'PREVAC'}, {'cycleId': 12520278.0, 'starttime': 1647303396, 'endtime': 1647305177, 'duration': 1781, 'type': 'DART TEST'}, {'cycleId': 12554508.0, 'starttime': 1647821300, 'endtime': 1647822560, 'duration': 1260, 'type': 'DART WARMUP'}, {'cycleId': 12554627.0, 'starttime': 1647822923, 'endtime': 1647825062, 'duration': 2139, 'type': 'LEAK TEST'}, {'cycleId': 12554750.0, 'starttime': 1647826563, 'endtime': 1647828589, 'duration': 2026, 'type': 'DART TEST'}, {'cycleId': 12554808.0, 'starttime': 1647828844, 'endtime': 1647830521, 'duration': 1677, 'type': 'DART TEST'}, {'cycleId': 12554901.0, 'starttime': 1647830753, 'endtime': 1647832384, 'duration': 1631, 'type': 'DART TEST'}, {'cycleId': 12555311.0, 'starttime': 1647832799, 'endtime': 1647837109, 'duration': 4310, 'type': 'PREVAC'}, {'cycleId': 12555814.0, 'starttime': 1647837334, 'endtime': 1647841811, 'duration': 4477, 'type': 'PREVAC'}, {'cycleId': 12556279.0, 'starttime': 1647842048, 'endtime': 1647847342, 'duration': 5294, 'type': 'PREVAC'}, {'cycleId': 12560099.0, 'starttime': 1647884549, 'endtime': 1647885204, 'duration': 655, 'type': 'DART WARMUP'}, {'cycleId': 12560244.0, 'starttime': 1647885356, 'endtime': 1647887461, 'duration': 2105, 'type': 'LEAK TEST'}, {'cycleId': 12562061.0, 'starttime': 1647907438, 'endtime': 1647908122, 'duration': 684, 'type': 'DART WARMUP'}, {'cycleId': 12562316.0, 'starttime': 1647910122, 'endtime': 1647912026, 'duration': 1904, 'type': 'LEAK TEST'}, {'cycleId': 12562649.0, 'starttime': 1647917367, 'endtime': 1647918779, 'duration': 1412, 'type': 'DART TEST'}, {'cycleId': 12562764.0, 'starttime': 1647919513, 'endtime': 1647920747, 'duration': 1234, 'type': 'DA ...

# %%
# Write to a json file which is then ready for further preprocessing

with open("with_cycle_data.json", "w") as file:
    json.dump(full_list, file)  # encode dict into JSON
print("Done writing dict into .json file")
# Out:
# Done writing dict into .json file

# %%
with open('cycleIDs_by_machine.json', 'r') as file:
    text = json.load(file)

for obj in text:
    devices = obj['devices']
    for device in devices:
        cycles = device['cycle_ids']
        for cycle in cycles:

            print(cf.fetch_cycle_json(int(cycle['cycleId']))['cycles'][0]['cycle_type'])
            break
        break
# Out:
# DART WARMUP
# DART WARMUP

# %%
# returns true if the alarm is during a cycle
# returns false if the alarm is in between cycles
def during(cycle, alarm_ts):
    return alarm_ts <= cycle['endtime'] and alarm_ts >= cycle['starttime']


# add alarm labels to each cyle 
def insert_alarm_to_cycle(device, alarms):
    cycle_ids = device['cycle_ids']
    alarms_num = len(alarms)
    cycle_nums = len(cycle_ids)
    end_times = [x['endtime'] for x in cycle_ids]
    alarms_ts = [x['alarm_ts'] for x in alarms]

    for alarm_ts in alarms_ts:

        last = True
        not_during = True
        for i in range(len(cycle_ids)):
            if (during(cycle_ids[i], alarm_ts)):
                print("condition 1 met")
                t = cycle_ids[i]['type']
                acc = 20
                j = i
                while j > -1 and acc > 0:
                    if cycle_ids[j]['type'] == t:
                        cycle_ids[j]['FSR Required'] = 1
                        acc -= 1
                    j -= 1
                # cycle_ids[i]['FSR Required'] = 1
                not_during = False
                last = False
                break
        
        if not_during:
            for i in range(len(cycle_ids)):
                if (alarm_ts - cycle_ids[i]['endtime'] < 0):
                     print('condition 2 met')
                     acc = 20
                     t = cycle_ids[i-1]['type']
                     j = i - 1
                     while j > -1 and acc > 0:
                        if cycle_ids[j]['type'] == t:
                            cycle_ids[j]['FSR Required'] = 1
                            acc -= 1
                        j -= 1
                    #  cycle_ids[i-1]['FSR Required'] = 1
                     last = False
                     break
        if last:
            print("condition 3 met")
            # for i in range(len(cycle_ids)-1 , len(cycle_ids)-11, - 1):
            t = cycle_ids[-1]['type']
            acc = 20
            j = len(cycle_ids)-1
            while (acc > 0 and j > -1):
                if cycle_ids[j]['type'] == t:
                    cycle_ids[j]['FSR Required'] = 1
                    acc -= 1
                j -= 1

# %%
# test for alarm addition

with open('test.json', 'r') as file:
    device = json.load(file)
alarms = [{"alarmLogId": 99999, 'alarm_ts':221}]
insert_alarm_to_cycle(device, alarms)
print(device)
# Out:
# condition 1 met
# {'deviceId': 4422, 'cycle_ids': [{'cycleId': 12433368.0, 'starttime': 0, 'endtime': 10, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465041.0, 'starttime': 20, 'endtime': 30, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 40, 'endtime': 50, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 60, 'endtime': 70, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 80, 'endtime': 90, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 100, 'endtime': 110, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 120, 'endtime': 130, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 140, 'endtime': 150, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 160, 'endtime': 170, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 180, 'endtime': 190, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 200, 'endtime': 210, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}, {'cycleId': 12465175.0, 'starttime': 220, 'endtime': 230, 'duration': 10, 'type': 'PREVAC', 'FSR Required': 1}]}

# %%
# retrieve alarm data, only for 'FSR Required' alarms, aka alarm priority = 1
# add alarm data to corresponding device data

# form a new json using cycle data (with alarm)
def add_alarm_data(full_list):
    counter = 0
    for obj in full_list:
        devices = obj['devices']
        for device in devices:
            device_id = device['deviceId']
            print(f'Device {device_id} alarming adding initiated')
            alarm_lst = []
            sql = f''' 
            SELECT Created_Date, CustomerDeviceAlarmLog_Id 
            FROM CustomerDeviceAlarmLog WHERE CustomerDeviceId = '{device_id}'
            AND AlarmPriority = 1 ORDER BY Created_Date ASC
            '''
            prod_cursor.execute(sql)
            alarms = prod_cursor.fetchall()
            if (len(alarms) == 0):
                continue
            for alarm in alarms:
                counter += 1
                row = list(alarm)
                row[0] = calendar.timegm(row[0].timetuple())
                d = {"alarmLogId": row[1], 'alarm_ts':row[0]}
                alarm_lst.append(d)
                break
            insert_alarm_to_cycle(device, alarm_lst)
    print(f'{counter} alarms added')
    return full_list

# %%
with open('with_cycle_data.json', 'r') as file:
    text = json.load(file)
full_data = add_alarm_data(text)

with open("full_data.json", "w") as file:
    json.dump(full_data, file) 
print("Done writing dict into .json file")
# Out:
# Device 4422 alarming adding initiated
# condition 2 met
# Device 4423 alarming adding initiated
# condition 2 met
# Device 6079 alarming adding initiated
# Device 6083 alarming adding initiated
# Device 6084 alarming adding initiated
# condition 3 met
# Device 5559 alarming adding initiated
# condition 2 met
# Device 4826 alarming adding initiated
# condition 2 met
# Device 4828 alarming adding initiated
# condition 2 met
# Device 5294 alarming adding initiated
# condition 2 met
# Device 5295 alarming adding initiated
# condition 2 met
# Device 5307 alarming adding initiated
# condition 2 met
# Device 5308 alarming adding initiated
# condition 2 met
# Device 5312 alarming adding initiated
# condition 2 met
# Device 5313 alarming adding initiated
# condition 1 met
# Device 5330 alarming adding initiated
# condition 2 met
# Device 2349 alarming adding initiated
# condition 2 met
# Device 2350 alarming adding initiated
# condition 2 met
# Device 2373 alarming adding initiated
# Device 2374 alarming adding initiated
# condition 2 met
# Device 4717 alarming adding initiated
# Device 4718 alarming adding initiated
# condition 2 met
# Device 699 alarming adding initiated
# condition 2 met
# Device 4969 alarming adding initiated
# condition 2 met
# Device 5126 alarming adding initiated
# condition 2 met
# Device 5127 alarming adding initiated
# condition 2 met
# Device 1427 alarming adding initiated
# condition 2 met
# Device 1428 alarming adding initiated
# condition 2 met
# Device 1429 alarming adding initiated
# condition 2 met
# Device 1430 alarming adding initiated
# Device 6001 alarming adding initiated
# condition 1 met
# Device 586 alarming adding initiated
# condition 2 met
# Device 587 alarming adding initiated
# condition 2 met
# Device 646 alarming adding initiated
# condition 2 met
# Device 647 alarming adding initiated
# condition 2 met
# Device 2463 alarming adding initiated
# condition 2 met
# Device 2464 alarming adding initiated
# condition 2 met
# Device 6665 alarming adding initiated
# Device 6699 alarming adding initiated
# Device 6671 alarming adding initiated
# Device 6698 alarming adding initiated
# Device 6729 alarming adding initiated
# Device 6748 alarming adding initiated
# Device 6750 alarming adding initiated
# Device 6731 alarming adding initiated
# Device 6733 alarming adding initiated
# Device 6730 alarming adding initiated
# Device 6185 alarming adding initiated
# condition 2 met
# Device 6186 alarming adding initiated
# Device 6189 alarming adding initiated
# Device 6190 alarming adding initiated
# Device 6311 alarming adding initiated
# condition 1 met
# Device 6312 alarming adding initiated
# Device 6313 alarming adding initiated
# Device 6317 alarming adding initiated
# Device 6321 alarming adding initiated
# Device 6325 alarming adding initiated
# Device 6402 alarming adding initiated
# Device 6404 alarming adding initiated
# condition 2 met
# Device 6408 alarming adding initiated
# Device 6416 alarming adding initiated
# Device 6433 alarming adding initiated
# condition 2 met
# Device 6443 alarming adding initiated
# Device 6672 alarming adding initiated
# Device 6689 alarming adding initiated
# Device 6766 alarming adding initiated
# Device 6768 alarming adding initiated
# Device 5785 alarming adding initiated
# Device 6798 alarming adding initiated
# Device 6800 alarming adding initiated
# Device 6732 alarming adding initiated
# Device 6882 alarming adding initiated
# Device 6810 alarming adding initiated
# Device 6771 alarming adding initiated
# Device 6700 alarming adding initiated
# Device 6673 alarming adding initiated
# Device 6583 alarming adding initiated
# Device 6584 alarming adding initiated
# Device 6622 alarming adding initiated
# Device 5226 alarming adding initiated
# Device 6277 alarming adding initiated
# condition 2 met
# Device 6306 alarming adding initiated
# Device 6459 alarming adding initiated
# Device 6466 alarming adding initiated
# Device 6467 alarming adding initiated
# Device 2504 alarming adding initiated
# condition 2 met
# 37 alarms added
# Done writing dict into .json file

# %%
with open("full_data.json", 'r') as file:
    pmcl1 = json.load(file)
    pmcl1 = pmcl1[1]
with open("pmcl_1.json", 'w') as file:
    json.dump(pmcl1, file)
